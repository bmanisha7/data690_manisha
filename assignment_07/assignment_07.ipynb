# %% [markdown]
# <a href="https://colab.research.google.com/github/bmanisha7/data690_manisha/blob/main/assignment_07/assignment_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assignment 06
# ### Note:
# - For visualization, you should use Plotly Express
# - Use use this notebook as your template and follow the instructions
#
# The first half of this assignment is a repeat of assignment 05.
#
# This gives you a chance to refresh.
#
# The second half is new and gives you a chance to perform additional practices.
#
# You also get a chance to use some of the Python libraries and techniques.
#
# The links to the zip file is:
#
# - https://data.ed.gov/dataset/college-scorecard-all-data-files-through-6-2020/resources (The page containing link to the zip file)
#
# - https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_01192021.zip (The link to download the zip file)
#
# You can upload the zip file there or run `!wget` command to retrieve it directly, then run `!unzip` command to extract files.
#
# You can also unzip and upload individual files to Colab.
#
# Your folder structure should look like this in your Colab enviroment:
# ```
# - assignment_07.ipynb
# - raw_data/
#         - ...
#         - 'MERGED1996_97_PP.csv',
#         - 'MERGED2015_16_PP.csv',
#         - ...
#         - 'MERGED2017_18_PP.csv'
#         - ...
# ```

# %%
# !wget https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_01192021.zip
# Out:
# --2021-10-14 20:07:04--  https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_01192021.zip
# Resolving ed-public-download.app.cloud.gov (ed-public-download.app.cloud.gov)... 15.205.92.235, 15.200.243.39, 2600:1f12:18a:7d01:29c7:6ff5:8ad8:c8f0, ...
# Connecting to ed-public-download.app.cloud.gov (ed-public-download.app.cloud.gov)|15.205.92.235|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 385541173 (368M) [application/zip]
# Saving to: ‘CollegeScorecard_Raw_Data_01192021.zip’
#
# CollegeScorecard_Ra 100%[===================>] 367.68M  35.6MB/s    in 12s
#
# 2021-10-14 20:07:16 (30.5 MB/s) - ‘CollegeScorecard_Raw_Data_01192021.zip’ saved [385541173/385541173]

# %%
# !unzip CollegeScorecard_Raw_Data_01192021.zip
# Out:
# Archive:  CollegeScorecard_Raw_Data_01192021.zip
#    creating: Raw Data Files/
#   inflating: Raw Data Files/MERGED2011_12_PP.csv
#   inflating: Raw Data Files/MERGED1999_00_PP.csv
#   inflating: Raw Data Files/MERGED2006_07_PP.csv
#   inflating: Raw Data Files/MERGED2014_15_PP.csv
#   inflating: Raw Data Files/Most-Recent-Cohorts-All-Data-Elements.csv
#   inflating: __MACOSX/Raw Data Files/._Most-Recent-Cohorts-All-Data-Elements.csv
#   inflating: Raw Data Files/MERGED2003_04_PP.csv
#   inflating: Raw Data Files/MERGED1996_97_PP.csv
#   inflating: Raw Data Files/FieldOfStudyData1516_1617_PP.csv
#   inflating: Raw Data Files/Most-Recent-Cohorts-Field-of-Study.csv
#   inflating: Raw Data Files/MERGED2012_13_PP.csv
#   inflating: Raw Data Files/MERGED2005_06_PP.csv
#   inflating: Raw Data Files/MERGED2009_10_PP.csv
#   inflating: Raw Data Files/FieldOfStudyData1617_1718_PP.csv
#   inflating: Raw Data Files/MERGED2018_19_PP.csv
#   inflating: Raw Data Files/MERGED2017_18_PP.csv
# ...

# %%
# <1> 
# Import libraries

#(Write code here)
import pandas as pd
import plotly.graph_objects as go
import os

# %%
# <2> 
# Display the current workin directory using os.getcwd()
# you would need to import a standard Python library called os which stands for operating system,
# so place that import statement in the previous cell.
# Since your notebook and your data files are not in # the same folder, 
# you want to make sure what is the current working folder and 
# how to access a data file in a different folder

#(Write code here)
os.getcwd()
# Out:
# '/content'

# %%
# <3> 
# os library has a method call listdir which generates a list of files in a directory/folder.
# use this method to assign the contents (list of file names) of the data folder to a variable and display it.
# # You can use ../ construct to traverse to the parent folder and then to another foloder parallel to the current folder

#(Write code here)
path = "/content/Raw Data Files/"
a = []
raw_files = os.listdir("/content/Raw Data Files")
for f in raw_files:
      a.append(f)
a.sort()
a
# Out:
# ['Crosswalks.zip',
#  'FieldOfStudyData1415_1516_PP.csv',
#  'FieldOfStudyData1516_1617_PP.csv',
#  'FieldOfStudyData1617_1718_PP.csv',
#  'MERGED1996_97_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2012_13_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED2017_18_PP.csv',
#  'MERGED2018_19_PP.csv',
#  'Most-Recent-Cohorts-All-Data-Elements.csv',
#  'Most-Recent-Cohorts-Field-of-Study.csv',
#  'data.yaml']

# %%
 # <4> 
# The folder contains files that are not the yearly data files
# write code to remove the unwanted files from the list vsriable 
# Note: don't remove/delete these files from the folder in your drive
# For example, use the file extension to only keep the csv files 
# or use the name patter - data file name begins with "MERGED"
# You can use the concept of list comprehension to write just 
# one line of code as well as using a for loop, your choice.

#(Write code here)
#import os, re, os.path
#pattern = "Field*"
#mypath = raw_files
#for root, dirs, files in os.walk(mypath):
#    for file in filter(lambda x: re.match(pattern, x), files):
#        os.remove(os.path.join(root, file))
 
 
#filter_data0= ( [i for i in a if 'Field' not in i])
#filter_data1 = ([i for i in filter_data0 if 'Most' not in i])
#filter_data2 = ([i for i in filter_data1 if 'C' not in i ])
#filter_data2 = filter_data1.pop(17)
#filter_data = ([i for i in filter_data1 if 'data' not in i ])
#(filter_data)
# Out:
# ['MERGED2012_13_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2018_19_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED1996_97_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'Crosswalks.zip',
#  'MERGED2017_18_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2003_04_PP.csv']

# %%
filter_files = [raw_files for raw_files in raw_files if 'MERGED' in raw_files]
filter_files
# Out:
# ['MERGED2012_13_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2018_19_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED1996_97_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED2017_18_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2003_04_PP.csv']

# %%
# <5> 
# Now that you have a clean list of the yearly files, you want to loop through them
# and read them into a dataframe one at a time. You only load six columns: 
# ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"].
# You should use "usecols" option of Pandas to avoid reading unwanted columns.
# You also want to add a new column call "YEAR" to differentiate the data frames from each other.
# The YEAR variable should be yyyy format so tht you can convert them into integer.
# if you use the format yyyy-yy (such as 1997-98 school year), you will not be able to convert them directly to integer
# if you use scatter plot, the YEAR needs to be converted to integer or float. 
# 
# You would use an empty list and append the yearly dataframes to the list.
# After all data files are loaded and appended to the list, you would use Pandas to concatenate them into a 
# new single data frame.
# Note: this exercise incorporates many techques we learned before
# - list (creating an empty, append an item to the list)
# - for loop 
# - read only the needed columns from a file (using usecols option)
# - add a new column to a data frame
# - concatenate multiple dataframes into a single one
# This exercise may appear a big challenging but it worths the effort. You will learn a lot and  love it. I promise.

#(Write code here)
list = []
for filename in filter_files:
    df_1 = pd.read_csv(path + filename, usecols = ["UNITID", "INSTNM", "STABBR", "REGION", "ADM_RATE", "TUITIONFEE_IN"])
    df_1['YEAR'] = filename[6:10]
    list.append(df_1)
df = pd.concat(list)
df
# Out:
#       UNITID  ...  YEAR
# 0     100636  ...  2012
# 1     100654  ...  2012
# 2     100663  ...  2012
# 3     100690  ...  2012
# 4     100706  ...  2012
# ...      ...  ...   ...
# 6668  444042  ...  2003
# 6669  444051  ...  2003
# 6670  444060  ...  2003
# 6671  444079  ...  2003
# 6672  444088  ...  2003
#
# [163331 rows x 7 columns]

# %%
# <6> 
# explore the new dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)

#(Write code here)
print("Number of Rows: ", df.shape[0])
print("Number of Columns: ", df.shape[1])
# Out:
# Number of Rows:  163331
# Number of Columns:  7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163331 entries, 0 to 6672
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   UNITID         163331 non-null  int64
#  1   INSTNM         163331 non-null  object
#  2   STABBR         163331 non-null  object
#  3   REGION         163330 non-null  float64
#  4   ADM_RATE       44912 non-null   float64
#  5   TUITIONFEE_IN  79195 non-null   float64
#  6   YEAR           163331 non-null  object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 10.0+ MB

# %%
df.head()
# Out:
#    UNITID                               INSTNM  ... TUITIONFEE_IN  YEAR
# 0  100636   Community College of the Air Force  ...           NaN  2012
# 1  100654             Alabama A & M University  ...        7182.0  2012
# 2  100663  University of Alabama at Birmingham  ...        6798.0  2012
# 3  100690                   Amridge University  ...        6800.0  2012
# 4  100706  University of Alabama in Huntsville  ...        8794.0  2012
#
# [5 rows x 7 columns]

# %%
df.tail()
# Out:
#       UNITID  ...  YEAR
# 6668  444042  ...  2003
# 6669  444051  ...  2003
# 6670  444060  ...  2003
# 6671  444079  ...  2003
# 6672  444088  ...  2003
#
# [5 rows x 7 columns]

# %%
df.sample(10)
# Out:
#       UNITID                                    INSTNM  ... TUITIONFEE_IN  YEAR
# 6080  444264             Cambridge Technical Institute  ...           NaN  2009
# 2295  185536                  Middlesex County College  ...        3374.0  2014
# 1427  154837      Central Baptist Theological Seminary  ...        6780.0  2011
# 318   114266                  Evergreen Valley College  ...        1326.0  2014
# 3314  220002  Hussian College-Daymar College Nashville  ...       15000.0  2017
# 7181  487083                           Protege Academy  ...           NaN  2015
# 1898  169220             Michigan School of Psychology  ...           NaN  2010
# 4186  230214   Paul Mitchell the School-Salt Lake City  ...           NaN  2007
# 3754  217961                          Converse College  ...       24500.0  2008
# 7094  461607                  Elite Cosmetology School  ...           NaN  2012
#
# [10 rows x 7 columns]

# %%
df[df.isna().any(axis=1)]
# Out:
#       UNITID  ...  YEAR
# 0     100636  ...  2012
# 3     100690  ...  2012
# 7     100760  ...  2012
# 8     100812  ...  2012
# 12    101028  ...  2012
# ...      ...  ...   ...
# 6666  444024  ...  2003
# 6667  444033  ...  2003
# 6669  444051  ...  2003
# 6671  444079  ...  2003
# 6672  444088  ...  2003
#
# [125241 rows x 7 columns]

# %%
df.describe() # used to get the statistics of the columns that are present in the dataframe.
# Out:
#              UNITID         REGION      ADM_RATE  TUITIONFEE_IN
# count  1.633310e+05  163330.000000  44912.000000   79195.000000
# mean   9.432395e+05       4.554693      0.692951   11665.636871
# std    4.571721e+06       2.189217      0.217058    9986.003542
# min    1.006360e+05       0.000000      0.000000       0.000000
# 25%    1.633380e+05       3.000000      0.555075    3776.000000
# 50%    2.127800e+05       5.000000      0.717500    9285.000000
# 75%    4.075680e+05       6.000000      0.857100   16148.000000
# max    4.914640e+07       9.000000      1.000000   74787.000000

# %%
# <7>
# the dataframe contains many years of data of all U.S. colleges.
# let's just look at UMBC
# filter/query the dataframe to retrieve only rows that belong to UMBC
# save the UMNC data to a new data frame. using a new variable 
# so that the old big data frame is still available for later use.

#(Write code here)
b = pd.DataFrame()
x = df.loc[df["INSTNM"].str.contains('University of Maryland-Baltimore County')]
c = b.append(x)
c
# Out:
#       UNITID                                   INSTNM  ... TUITIONFEE_IN  YEAR
# 1660  163268  University of Maryland-Baltimore County  ...        9764.0  2012
# 1694  163268  University of Maryland-Baltimore County  ...        9467.0  2011
# 1926  163268  University of Maryland-Baltimore County  ...        5490.0  2000
# 1415  163268  University of Maryland-Baltimore County  ...       11778.0  2018
# 1955  163268  University of Maryland-Baltimore County  ...           NaN  1999
# 1819  163268  University of Maryland-Baltimore County  ...        8520.0  2005
# 1799  163268  University of Maryland-Baltimore County  ...        8622.0  2006
# 2049  163268  University of Maryland-Baltimore County  ...           NaN  1997
# 1915  163268  University of Maryland-Baltimore County  ...        5910.0  2001
# 1830  163268  University of Maryland-Baltimore County  ...        8020.0  2004
# 2151  163268  University of Maryland-Baltimore County  ...           NaN  1996
# ...

# %%
# <8>
# Explore this UMBC dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)

#(Write code here)
c.shape
# Out:
# (23, 7)

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 1660 to 1873
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UNITID         23 non-null     int64
#  1   INSTNM         23 non-null     object
#  2   STABBR         23 non-null     object
#  3   REGION         23 non-null     float64
#  4   ADM_RATE       18 non-null     float64
#  5   TUITIONFEE_IN  19 non-null     float64
#  6   YEAR           23 non-null     object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.4+ KB

# %%
c.head()
# Out:
#       UNITID                                   INSTNM  ... TUITIONFEE_IN  YEAR
# 1660  163268  University of Maryland-Baltimore County  ...        9764.0  2012
# 1694  163268  University of Maryland-Baltimore County  ...        9467.0  2011
# 1926  163268  University of Maryland-Baltimore County  ...        5490.0  2000
# 1415  163268  University of Maryland-Baltimore County  ...       11778.0  2018
# 1955  163268  University of Maryland-Baltimore County  ...           NaN  1999
#
# [5 rows x 7 columns]

# %%
c.tail()
# Out:
#       UNITID                                   INSTNM  ... TUITIONFEE_IN  YEAR
# 1478  163268  University of Maryland-Baltimore County  ...       11518.0  2017
# 1629  163268  University of Maryland-Baltimore County  ...       10068.0  2013
# 1767  163268  University of Maryland-Baltimore County  ...        8780.0  2008
# 1745  163268  University of Maryland-Baltimore County  ...        8872.0  2009
# 1873  163268  University of Maryland-Baltimore County  ...        7388.0  2003
#
# [5 rows x 7 columns]

# %%
c.sample(10)
# Out:
#       UNITID                                   INSTNM  ... TUITIONFEE_IN  YEAR
# 1610  163268  University of Maryland-Baltimore County  ...       10384.0  2014
# 1926  163268  University of Maryland-Baltimore County  ...        5490.0  2000
# 1819  163268  University of Maryland-Baltimore County  ...        8520.0  2005
# 1955  163268  University of Maryland-Baltimore County  ...           NaN  1999
# 1873  163268  University of Maryland-Baltimore County  ...        7388.0  2003
# 1629  163268  University of Maryland-Baltimore County  ...       10068.0  2013
# 2049  163268  University of Maryland-Baltimore County  ...           NaN  1997
# 1830  163268  University of Maryland-Baltimore County  ...        8020.0  2004
# 1799  163268  University of Maryland-Baltimore County  ...        8622.0  2006
# 1915  163268  University of Maryland-Baltimore County  ...        5910.0  2001
#
# [10 rows x 7 columns]

# %%
c[c.isna().any(axis=1)]
# Out:
#       UNITID                                   INSTNM  ... TUITIONFEE_IN  YEAR
# 1926  163268  University of Maryland-Baltimore County  ...        5490.0  2000
# 1955  163268  University of Maryland-Baltimore County  ...           NaN  1999
# 2049  163268  University of Maryland-Baltimore County  ...           NaN  1997
# 2151  163268  University of Maryland-Baltimore County  ...           NaN  1996
# 1982  163268  University of Maryland-Baltimore County  ...           NaN  1998
#
# [5 rows x 7 columns]

# %%
c.describe()
# Out:
#          UNITID  REGION   ADM_RATE  TUITIONFEE_IN
# count      23.0    23.0  18.000000      19.000000
# mean   163268.0     2.0   0.640694    9004.842105
# std         0.0     0.0   0.052728    1825.795421
# min    163268.0     2.0   0.568300    5490.000000
# 25%    163268.0     2.0   0.597600    8270.000000
# 50%    163268.0     2.0   0.632100    8872.000000
# 75%    163268.0     2.0   0.689375   10226.000000
# max    163268.0     2.0   0.717400   11778.000000

# %%
# <9> 
# Plot UMBC's in-state tution overtime from 1996 to 2019 using Bar Chart

#(Write code here)
fig = go.Figure()

trace_umbc = go.Bar(
    x=c["YEAR"],
    y=c["TUITIONFEE_IN"]
)
fig.add_trace(trace_umbc)

fig.update_layout(
    title="UMBC",
    xaxis={"title":"year"},
    yaxis={"title":"instate tution fee"}
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dc270410-04e8-44e1-b93a-34b1f81f4193" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dc270410-04e8-44e1-b93a-34b1f81f4193")) {
#                     Plotly.newPlot(
#                         'dc270410-04e8-44e1-b93a-34b1f81f4193',
# ...

# %%
c=c.sort_values(by='YEAR')
c.plot(x="YEAR", y=["TUITIONFEE_IN"], kind="bar")

# %%
# <10> 
# Plot UMBC's in-state tution overtime from 1996 to 2019 using Line Chart

#(Write code here)
fig = go.Figure()

trace_umbc = go.Line(
    x=c["YEAR"],
    y=c["TUITIONFEE_IN"]
)
fig.add_trace(trace_umbc)

fig.update_layout(
    title="UMBC",
    xaxis={"title":"year"},
    yaxis={"title":"instate tution fee"}
)


fig.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:385: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9d5bf27b-21d4-444b-bad6-279d0e572276" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
# ...

# %%
c=c.sort_values(by='YEAR')
c.plot(x="YEAR", y=["TUITIONFEE_IN"], kind="line")

# %%
# <11>
# Now let's look at the tuition growth rate year over year
# We need to calculate UMBC tuition change percentage each year
# First convert the TUITIONFEE_IN column to a Python List

#(Write code here)
umbc_tuition = c['TUITIONFEE_IN'].tolist()
umbc_tuition
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  5490.0,
#  5910.0,
#  6362.0,
#  7388.0,
#  8020.0,
#  8520.0,
#  8622.0,
#  8708.0,
#  8780.0,
#  8872.0,
#  9171.0,
#  9467.0,
#  9764.0,
#  10068.0,
#  10384.0,
#  11006.0,
#  11264.0,
#  11518.0,
#  11778.0]

# %%
# Loop through the list and calculate the % change each year over the prior year
# This takes some effort. Not hard, just some abstract/logical thinking and some experiments
# Have fun on this one

 #(Write code here)
old_tuition = 0
tuition_diff = []
for fee in umbc_tuition:
    if fee == fee:
        if old_tuition == 0:
            old_tuition = fee
        umbc_pctchange = ((fee - old_tuition)/old_tuition) * 100
        tuition_diff.append(umbc_pctchange)
    else:
        tuition_diff.append(fee)
    old_tuition = fee

tuition_diff
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  7.650273224043716,
#  7.648054145516074,
#  16.12700408676517,
#  8.554412560909583,
#  6.234413965087282,
#  1.1971830985915493,
#  0.9974483878450475,
#  0.8268259072117593,
#  1.0478359908883828,
#  3.370153291253381,
#  3.227565151019518,
#  3.1372134783986483,
#  3.11347808275297,
#  3.1386571315057608,
#  5.989984591679507,
#  2.344175904052335,
#  2.254971590909091,
#  2.2573363431151243]

# %%
# The resulting number has many decimal points which are unnecessary and not visually appealing.
# Round up the percentage to two decimal points
# You can use for loop. Or better, use list comprehension for simplicity/brevity

#(Write code here)
tuition_diff = [round(pctchange, 2) for pctchange in tuition_diff]
tuition_diff
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  7.65,
#  7.65,
#  16.13,
#  8.55,
#  6.23,
#  1.2,
#  1.0,
#  0.83,
#  1.05,
#  3.37,
#  3.23,
#  3.14,
#  3.11,
#  3.14,
#  5.99,
#  2.34,
#  2.25,
#  2.26]

# %%
# Add the list of the percentages to the dataframe as a new column ("PCT_CHANGE")
# Not as hard as you may think. If you get stuck, you think too hard. 
# Google it and you will find the answer.

#(Write code here)
c['PCT_CHANGE'] = tuition_diff
c
# Out:
#       UNITID                                   INSTNM  ...  YEAR  PCT_CHANGE
# 2151  163268  University of Maryland-Baltimore County  ...  1996         NaN
# 2049  163268  University of Maryland-Baltimore County  ...  1997         NaN
# 1982  163268  University of Maryland-Baltimore County  ...  1998         NaN
# 1955  163268  University of Maryland-Baltimore County  ...  1999         NaN
# 1926  163268  University of Maryland-Baltimore County  ...  2000         NaN
# 1915  163268  University of Maryland-Baltimore County  ...  2001        7.65
# 1893  163268  University of Maryland-Baltimore County  ...  2002        7.65
# 1873  163268  University of Maryland-Baltimore County  ...  2003       16.13
# 1830  163268  University of Maryland-Baltimore County  ...  2004        8.55
# 1819  163268  University of Maryland-Baltimore County  ...  2005        6.23
# 1799  163268  University of Maryland-Baltimore County  ...  2006        1.20
# ...

# %%
# Finally, we can make the plot tuition growth rate year over year - bar first, then line chart

# (write code here)

fig = go.Figure()

trace_umbc = go.Bar(
    x=c["YEAR"],
    y=c["PCT_CHANGE"]
)
fig.add_trace(trace_umbc)

fig.update_layout(
    title="UMBC",
    xaxis={"title":"year"},
    yaxis={"title":"percentage growth"}
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="320923b8-b392-4c0c-96e0-eb4954b17d73" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("320923b8-b392-4c0c-96e0-eb4954b17d73")) {
#                     Plotly.newPlot(
#                         '320923b8-b392-4c0c-96e0-eb4954b17d73',
# ...

# %%
c=c.sort_values(by='YEAR')
c.plot(x="YEAR", y=["PCT_CHANGE"], kind="bar")

# %%
fig = go.Figure()

trace_umbc = go.Line(
    x=c["YEAR"],
    y=c["PCT_CHANGE"]
)
fig.add_trace(trace_umbc)

fig.update_layout(
    title="UMBC",
    xaxis={"title":"year"},
    yaxis={"title":"percentage growth"}
)


fig.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:385: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f8137082-5e50-46c5-9fd3-1685ed07cb36" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
# ...

# %%
c=c.sort_values(by='YEAR')
c.plot(x="YEAR", y=["PCT_CHANGE"], kind="line")

# %%
# <12>
# Since we want to do the same calculation for JHU. 
# Instead of doing it piecemeal as we did for UMBC
# Let's create a function which can be reused for any college.
# This function takes a list of tuitions and return a list of percentage changes year over year
# This function can be used later 

#(Write code here)

def pct_change(df_inst):
  tuition = df_inst['TUITIONFEE_IN'].tolist()
  old_tuition = 0
  tuition_diff = []
  for fee in tuition:
      if fee == fee:
          if old_tuition == 0:
              old_tuition = fee
          pctchange = ((fee - old_tuition)/old_tuition) * 100
          tuition_diff.append(pctchange)
      else:
          tuition_diff.append(fee)
      old_tuition = fee
  tuition_diff = [round(pctchange, 2) for pctchange in tuition_diff]
  df_inst['PCT_CHANGE'] = tuition_diff
  return df_inst

# %%
# <13>
# the dataframe contains many years of data of all U.S. colleges.
# let's just look at JHU
# filter/query the dataframe to retrieve only rows that belong to JHU
# save the JHU data to a new data frame. using a new variable 
# so that the old big data frame is still available for later use.

#(Write code here)
df_jhu = df.loc[df["INSTNM"].str.contains('Johns Hopkins University')]
df_jhu
# Out:
#       UNITID                    INSTNM STABBR  ...  ADM_RATE  TUITIONFEE_IN  YEAR
# 1653  162928  Johns Hopkins University     MD  ...    0.1843        43390.0  2012
# 1687  162928  Johns Hopkins University     MD  ...    0.1940        42280.0  2011
# 1917  162928  Johns Hopkins University     MD  ...       NaN        24930.0  2000
# 1410  162928  Johns Hopkins University     MD  ...    0.1148        53740.0  2018
# 1946  162928  Johns Hopkins University     MD  ...       NaN            NaN  1999
# 1812  162928  Johns Hopkins University     MD  ...    0.3509        31620.0  2005
# 1792  162928  Johns Hopkins University     MD  ...    0.2792        33900.0  2006
# 2039  162928  Johns Hopkins University     MD  ...       NaN            NaN  1997
# 1906  162928  Johns Hopkins University     MD  ...    0.3431        26210.0  2001
# 1823  162928  Johns Hopkins University     MD  ...    0.3071        30140.0  2004
# ...

# %%
# <14> 
# Plot JHU's in-state tuition overtime from 1996 to 2019. 
# Let's plot bar and line chart together

#(Write code here)

fig = go.Figure()

trace_jhu = go.Bar(
    x=df_jhu["YEAR"],
    y=df_jhu["TUITIONFEE_IN"]
)
fig.add_trace(trace_jhu)

fig.update_layout(
    title="JHU",
    xaxis={"title":"year"},
    yaxis={"title":"instate tution fee"}
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0b9bcaa4-b1f9-4de4-88eb-7553bd40c9fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0b9bcaa4-b1f9-4de4-88eb-7553bd40c9fd")) {
#                     Plotly.newPlot(
#                         '0b9bcaa4-b1f9-4de4-88eb-7553bd40c9fd',
# ...

# %%
df_jhu=df_jhu.sort_values(by='YEAR')
df_jhu.plot(x="YEAR", y=["TUITIONFEE_IN"], kind="bar")

# %%
fig = go.Figure()

trace_jhu = go.Line(
    x=df_jhu["YEAR"],
    y=df_jhu["TUITIONFEE_IN"]
)
fig.add_trace(trace_jhu)

fig.update_layout(
    title="JHU",
    xaxis={"title":"year"},
    yaxis={"title":"instate tution fee"}
)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:385: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b83c8aac-a967-49ff-8124-4c54b43df800" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
# ...

# %%
df_jhu=df_jhu.sort_values(by='YEAR')
df_jhu.plot(x="YEAR", y=["TUITIONFEE_IN"], kind="line")

# %%
# <15>
# Let's calculate the JHU tuition percentge growth using the function defined earlier

#(Write code here)

# <16>
# Add the list of percentage changes to the dataframe as a new column ("PCT_CHANGE")

#(Write code here)

pct_change(df_jhu)
df_jhu
# Out:
#       UNITID                    INSTNM STABBR  ...  TUITIONFEE_IN  YEAR  PCT_CHANGE
# 2139  162928  Johns Hopkins University     MD  ...            NaN  1996         NaN
# 2039  162928  Johns Hopkins University     MD  ...            NaN  1997         NaN
# 1973  162928  Johns Hopkins University     MD  ...            NaN  1998         NaN
# 1946  162928  Johns Hopkins University     MD  ...            NaN  1999         NaN
# 1917  162928  Johns Hopkins University     MD  ...        24930.0  2000         NaN
# 1906  162928  Johns Hopkins University     MD  ...        26210.0  2001        5.13
# 1884  162928  Johns Hopkins University     MD  ...        27390.0  2002        4.50
# 1865  162928  Johns Hopkins University     MD  ...        28730.0  2003        4.89
# 1823  162928  Johns Hopkins University     MD  ...        30140.0  2004        4.91
# 1812  162928  Johns Hopkins University     MD  ...        31620.0  2005        4.91
# ...

# %%
# <17> Make a bar plot of the JHU percentage changes tuitions over time

#(Write code here)
fig = go.Figure()

trace_jhu = go.Bar(
    x=df_jhu["YEAR"],
    y=df_jhu["PCT_CHANGE"]
)
fig.add_trace(trace_jhu)

fig.update_layout(
    title="JHU",
    xaxis={"title":"year"},
    yaxis={"title":"percentage growth"}
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bb8fd24f-e07f-41c3-9513-4157c3040163" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bb8fd24f-e07f-41c3-9513-4157c3040163")) {
#                     Plotly.newPlot(
#                         'bb8fd24f-e07f-41c3-9513-4157c3040163',
# ...

# %%
# <18>
# In order to plot both UMBC and JHU tuition change over time in the same plot,
# we need to combine the two datasets using the common key of YEAR 
# First make a umbc2 dataframe with only two columns needed. WE don't need other columns.
# Also change the column name from "PCT_CHANGE" to "UMBC_PCT" in preparation for the merge.
# This is because both umbc and jhu dataframe have the same column name "PCT_CHANGE",
# We rename them to there is no collision during the merge. BTW, Pandas handles collision gracefully,
# Feel free to try it without changing the column names.

#(Write code here)

df_umbc = c[["YEAR","PCT_CHANGE"]]
df_umbc.rename(columns={'PCT_CHANGE':'UMBC_PCT'}, inplace=True)
df_umbc
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       YEAR  UMBC_PCT
# 2151  1996       NaN
# 2049  1997       NaN
# 1982  1998       NaN
# 1955  1999       NaN
# 1926  2000       NaN
# 1915  2001      7.65
# 1893  2002      7.65
# 1873  2003     16.13
# 1830  2004      8.55
# 1819  2005      6.23
# 1799  2006      1.20
# 1779  2007      1.00
# 1767  2008      0.83
# 1745  2009      1.05
# 1710  2010      3.37
# 1694  2011      3.23
# 1660  2012      3.14
# 1629  2013      3.11
# 1610  2014      3.14
# 1555  2015      5.99
# 1510  2016      2.34
# 1478  2017      2.25
# 1415  2018      2.26

# %%
# Then make a jhu2 dataframe with only two columns needed. WE don't need other columns.
# Also change the column name from "PCT_CHANGE" to "JHU_PCT"  in preparation for the merge

#(Write code here)
df_jhu1 = df_jhu[["YEAR","PCT_CHANGE"]]
df_jhu1.rename(columns={'PCT_CHANGE':'JHU_PCT'}, inplace=True)
df_jhu1
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       YEAR  JHU_PCT
# 2139  1996      NaN
# 2039  1997      NaN
# 1973  1998      NaN
# 1946  1999      NaN
# 1917  2000      NaN
# 1906  2001     5.13
# 1884  2002     4.50
# 1865  2003     4.89
# 1823  2004     4.91
# 1812  2005     4.91
# 1792  2006     7.21
# 1772  2007     5.90
# 1760  2008     5.01
# 1738  2009     3.85
# 1703  2010     3.91
# 1687  2011     3.93
# 1653  2012     2.63
# 1622  2013     4.79
# 1603  2014     3.50
# 1548  2015     3.51
# 1503  2016     3.49
# 1473  2017     3.49
# 1410  2018     3.01

# %%
# Now, merger the two data frames
# and display the new dataframe

#(Write code here)

df_pctchange_mrge = pd.merge(
    left = df_umbc, 
    right = df_jhu1, 
    left_on = 'YEAR', 
    right_on='YEAR'
    )
df_pctchange_mrge
# Out:
#     YEAR  UMBC_PCT  JHU_PCT
# 0   1996       NaN      NaN
# 1   1997       NaN      NaN
# 2   1998       NaN      NaN
# 3   1999       NaN      NaN
# 4   2000       NaN      NaN
# 5   2001      7.65     5.13
# 6   2002      7.65     4.50
# 7   2003     16.13     4.89
# 8   2004      8.55     4.91
# 9   2005      6.23     4.91
# 10  2006      1.20     7.21
# 11  2007      1.00     5.90
# 12  2008      0.83     5.01
# 13  2009      1.05     3.85
# 14  2010      3.37     3.91
# 15  2011      3.23     3.93
# 16  2012      3.14     2.63
# 17  2013      3.11     4.79
# 18  2014      3.14     3.50
# 19  2015      5.99     3.51
# 20  2016      2.34     3.49
# 21  2017      2.25     3.49
# 22  2018      2.26     3.01

# %%
# Plot UMBC and JHU separately on the same plot 
# However, this does not work since the bars overlap.

#(Write code here)

fig = go.Figure()

trace_merged = go.Bar(
    x=df_pctchange_mrge["YEAR"],
    y=df_pctchange_mrge['UMBC_PCT'],
    name="UMBC"
)

trace_merged1 = go.Bar(
    x=df_pctchange_mrge["YEAR"],
    y=df_pctchange_mrge['JHU_PCT'],
    name="JHU"
)

fig.add_trace(trace_merged)
fig.add_trace(trace_merged1)


fig.update_layout(
    title="UMBC vs JHU",
    xaxis={"title":"Year"},
    yaxis={"title":"percentage change"}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ea6f18af-8b78-4639-9dd8-5c6f16f242c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ea6f18af-8b78-4639-9dd8-5c6f16f242c7")) {
#                     Plotly.newPlot(
#                         'ea6f18af-8b78-4639-9dd8-5c6f16f242c7',
# ...

# %%
# Plot them together using y=["UMBC_PCT","JHU_PCT"] option of bar plot

#(Write code here)
df_pctchange_mrge.plot.bar(x = 'YEAR', y = ['UMBC_PCT', 'JHU_PCT'], figsize = (20, 15))

# %%
# Plot them together using y=["UMBC_PCT","JHU_PCT"] option of line plot

#(Write code here)

fig = go.Figure()

trace_merged = go.Line(
    x=df_pctchange_mrge["YEAR"],
    y=df_pctchange_mrge['UMBC_PCT'],
    name="UMBC"
)

trace_merged1 = go.Line(
    x=df_pctchange_mrge["YEAR"],
    y=df_pctchange_mrge['JHU_PCT'],
    name="JHU"
)

fig.add_trace(trace_merged)
fig.add_trace(trace_merged1)


fig.update_layout(
    title="UMBC vs JHU",
    xaxis={"title":"Year"},
    yaxis={"title":"percentage change"}
)

fig.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:385: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f962e484-41f6-4d57-a707-f31afac68167" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
# ...

# %%
df_pctchange_mrge.plot.line(x = 'YEAR', y = ['UMBC_PCT', 'JHU_PCT'], figsize = (20, 15))

# %%
# <19> 
# document your observation/conclusion of the comparison plots (bar/line)
# use the following Markdown cell

# %% [markdown]
# #### Based on my observation of the plots
# - From the above graphs we can see both universities growth with respect to the in-state fee per year. We can compare them by using bar graph and line graph accordingly and we can easily understand about the data represented.
# - The highest difference in percentage changes between UMBC and JHU was observed in the year 2003 with 11.24. The least difference was observed in the year 2012 with 0.51.
# - We can observe that UMBC has great percentage change in its in-tutition fees than the JHU.

# %%
# The end.
